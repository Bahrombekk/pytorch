# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/pytorch/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Neural_Network_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from  sklearn.datasets import make_regression

# %% [markdown]
# #Data 1x1

# %%
x,y=make_regression(n_samples=5,n_features=1,n_targets=1,random_state=True)

# %%
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
plt.scatter(x,y)

# %%
model=torch.nn.Linear(in_features=1,out_features=1)

# %%
critereon=torch.nn.MSELoss()
l=0.1
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=5
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {} , loss {}".format(i,loss.item()))
# Out:
# i 0 , loss 0.5899660587310791
# i 1 , loss 0.45683911442756653
# i 2 , loss 0.3644985854625702
# i 3 , loss 0.30954375863075256
# i 4 , loss 0.2837337851524353

# %%
plt.plot(loss_data)

# %%
x,y=make_regression(n_samples=5,n_features=1,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/10

# %%
plt.scatter(x,y)

# %%
model=torch.nn.Linear(in_features=1,out_features=1)
critereon=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=50
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {} , loss {}".format(i,loss.item()))
# Out:
# i 0 , loss 18.322856903076172
# i 1 , loss 18.313318252563477
# i 2 , loss 18.30446434020996
# i 3 , loss 18.296018600463867
# i 4 , loss 18.287904739379883
# i 5 , loss 18.280088424682617
# i 6 , loss 18.272563934326172
# i 7 , loss 18.265335083007812
# i 8 , loss 18.25840950012207
# i 9 , loss 18.251798629760742
# i 10 , loss 18.245515823364258
# i 11 , loss 18.23957633972168
# i 12 , loss 18.233993530273438
# i 13 , loss 18.228784561157227
# i 14 , loss 18.223962783813477
# i 15 , loss 18.21954345703125
# i 16 , loss 18.215539932250977
# i 17 , loss 18.21196746826172
# i 18 , loss 18.208837509155273
# i 19 , loss 18.206159591674805
# i 20 , loss 18.203948974609375
# i 21 , loss 18.202207565307617
# i 22 , loss 18.200946807861328
# i 23 , loss 18.200170516967773
# i 24 , loss 18.199880599975586
# i 25 , loss 18.200075149536133
# i 26 , loss 18.200754165649414
# i 27 , loss 18.201906204223633
# i 28 , loss 18.203527450561523
# i 29 , loss 18.20560073852539
# i 30 , loss 18.20810890197754
# i 31 , loss 18.21102523803711
# i 32 , loss 18.214326858520508
# i 33 , loss 18.217971801757812
# i 34 , loss 18.221921920776367
# i 35 , loss 18.226133346557617
# i 36 , loss 18.23055076599121
# i 37 , loss 18.2351131439209
# i 38 , loss 18.239757537841797
# i 39 , loss 18.244415283203125
# i 40 , loss 18.249013900756836
# i 41 , loss 18.25348663330078
# i 42 , loss 18.257768630981445
# i 43 , loss 18.261795043945312
# i 44 , loss 18.265525817871094
# i 45 , loss 18.26892852783203
# i 46 , loss 18.271982192993164
# i 47 , loss 18.274690628051758
# i 48 , loss 18.277067184448242
# i 49 , loss 18.279146194458008

# %%
plt.plot(loss_data)

# %%
x,y=make_regression(n_samples=6,n_features=1,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
plt.scatter(x,y)

# %%
model=torch.nn.Linear(in_features=1,out_features=1)
critereon=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=50
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {}, loss {}".format(i,loss.item()))
# Out:
# i 0, loss 0.3394754230976105
# i 1, loss 0.33300119638442993
# i 2, loss 0.32737770676612854
# i 3, loss 0.3224274516105652
# i 4, loss 0.31810981035232544
# i 5, loss 0.314415842294693
# i 6, loss 0.31132179498672485
# i 7, loss 0.30871787667274475
# i 8, loss 0.3063214123249054
# i 9, loss 0.30382299423217773
# i 10, loss 0.30119407176971436
# i 11, loss 0.29857656359672546
# i 12, loss 0.2961046099662781
# i 13, loss 0.2938728630542755
# i 14, loss 0.29194751381874084
# i 15, loss 0.2903774082660675
# i 16, loss 0.2892002761363983
# i 17, loss 0.2884461283683777
# i 18, loss 0.288139283657074
# i 19, loss 0.28829920291900635
# i 20, loss 0.2889407277107239
# i 21, loss 0.29007455706596375
# i 22, loss 0.29170677065849304
# i 23, loss 0.2938385307788849
# i 24, loss 0.2964658737182617
# i 25, loss 0.2995786666870117
# i 26, loss 0.30316004157066345
# i 27, loss 0.30718541145324707
# i 28, loss 0.3116213083267212
# i 29, loss 0.3164241313934326
# i 30, loss 0.3215385675430298
# i 31, loss 0.3268962502479553
# i 32, loss 0.33241379261016846
# i 33, loss 0.3379915952682495
# i 34, loss 0.34351247549057007
# i 35, loss 0.34884196519851685
# i 36, loss 0.3538293242454529
# i 37, loss 0.35831186175346375
# i 38, loss 0.3621219992637634
# i 39, loss 0.36509859561920166
# i 40, loss 0.36710071563720703
# i 41, loss 0.368022620677948
# i 42, loss 0.36780568957328796
# i 43, loss 0.3664447069168091
# i 44, loss 0.3639875054359436
# i 45, loss 0.3605278730392456
# i 46, loss 0.3561955690383911
# i 47, loss 0.3511447608470917
# i 48, loss 0.3455432951450348
# i 49, loss 0.33956390619277954

# %%
plt.plot(loss_data)

# %% [markdown]
# #Dara 2x1

# %%
x,y=make_regression(n_samples=5,n_features=2,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
model=torch.nn.Linear(in_features=2,out_features=1)
critereon=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=15
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {}, loss {}".format(i,loss.item()))
# Out:
# i 0, loss 1.2936813831329346
# i 1, loss 1.2529749870300293
# i 2, loss 1.2153090238571167
# i 3, loss 1.1795448064804077
# i 4, loss 1.1453372240066528
# i 5, loss 1.1125707626342773
# i 6, loss 1.0812208652496338
# i 7, loss 1.0513043403625488
# i 8, loss 1.0228582620620728
# i 9, loss 0.9959264397621155
# i 10, loss 0.9705498218536377
# i 11, loss 0.9467558264732361
# i 12, loss 0.9245442152023315
# i 13, loss 0.9038674831390381
# i 14, loss 0.8846017718315125

# %%
plt.plot(loss_data)

# %%
x,y=make_regression(n_samples=10,n_features=2,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
model=torch.nn.Linear(in_features=2,out_features=1)
criterion=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=25
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {} , loss {}".format(i,loss.item()))
# Out:
# i 0 , loss 1.8989338874816895
# i 1 , loss 1.8335283994674683
# i 2 , loss 1.771838665008545
# i 3 , loss 1.712038516998291
# i 4 , loss 1.653537392616272
# i 5 , loss 1.5960986614227295
# i 6 , loss 1.5396296977996826
# i 7 , loss 1.4841055870056152
# i 8 , loss 1.4295381307601929
# i 9 , loss 1.3759613037109375
# i 10 , loss 1.323423147201538
# i 11 , loss 1.2719804048538208
# i 12 , loss 1.2216955423355103
# i 13 , loss 1.1726351976394653
# i 14 , loss 1.124868631362915
# i 15 , loss 1.0784660577774048
# i 16 , loss 1.0334985256195068
# i 17 , loss 0.9900370240211487
# i 18 , loss 0.9481519460678101
# i 19 , loss 0.9079121351242065
# i 20 , loss 0.8693855404853821
# i 21 , loss 0.8326376080513
# i 22 , loss 0.797731876373291
# i 23 , loss 0.7647289037704468
# i 24 , loss 0.733686625957489

# %%
plt.plot(loss_data)

# %% [markdown]
# #Data set 1x1

# %%
data=pd.read_csv("https://raw.githubusercontent.com/JavohirJalilov/Regression/master/Salary_Data.csv")

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data=np.array(data)
x=data[:,0].reshape(-1,1)
x=torch.tensor(x,dtype=torch.float32)/10
y=data[:,1]
y=torch.tensor(y,dtype=torch.float32)/100000

# %%
x
# Out:
# tensor([[0.1100],
#         [0.1300],
#         [0.1500],
#         [0.2000],
#         [0.2200],
#         [0.2900],
#         [0.3000],
#         [0.3200],
#         [0.3200],
#         [0.3700],
#         [0.3900],
#         [0.4000],
#         [0.4000],
#         [0.4100],
#         [0.4500],
#         [0.4900],
#         [0.5100],
#         [0.5300],
#         [0.5900],
#         [0.6000],
#         [0.6800],
#         [0.7100],
#         [0.7900],
#         [0.8200],
#         [0.8700],
#         [0.9000],
#         [0.9500],
#         [0.9600],
#         [1.0300],
#         [1.0500]])

# %%
plt.scatter(x,y)

# %%
model=torch.nn.Linear(in_features=1,out_features=1)
critereon=torch.nn.MSELoss()
l=0.1
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=5
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {}, loss {}".format(i,loss.item()))
# Out:
# i 0, loss 0.8371300101280212
# i 1, loss 0.5907505750656128
# i 2, loss 0.397230863571167
# i 3, loss 0.24985778331756592
# i 4, loss 0.1478755623102188

# %%
plt.plot(loss_data)

# %% [markdown]
# #Data set 2x1

# %%
# !wget https://raw.githubusercontent.com/JavohirJalilov/Datasets/main/Regression/computer_price.csv
# Out:
# --2023-06-14 14:13:16--  https://raw.githubusercontent.com/JavohirJalilov/Datasets/main/Regression/computer_price.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179 [text/plain]
# Saving to: ‘computer_price.csv’
#
# computer_price.csv  100%[===================>]     179  --.-KB/s    in 0s
#
# 2023-06-14 14:13:16 (4.76 MB/s) - ‘computer_price.csv’ saved [179/179]

# %%
data=pd.read_csv("computer_price.csv")
data
# Out:
#     CPU(MHz)  RAM(GB)  Price(USD)
# 0       1100        4         280
# 1       1600        4         300
# 2       1000        8         350
# 3       1500       32         500
# 4       2000        4         500
# 5       2200       16         700
# 6       2600       32        1050
# 7       2100        8         620
# 8       2400       12         780
# 9       3000        8        1000
# 10      3200        8        1100
# 11      1700       16         510

# %%
x=data[["CPU(MHz)","RAM(GB)"]]
x=np.array(x)
x=torch.tensor(x,dtype=torch.float32)/100
y=data[["Price(USD)"]]
y=np.array(y)
y=torch.tensor(y,dtype=torch.float32)/1000

# %%
model=torch.nn.Linear(in_features=2,out_features=1)
critereon=torch.nn.MSELoss()
l=0.1
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=5
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {}, loss {}".format(i,loss.item()))
# Out:
# i 0, loss 102.3315658569336
# i 1, loss 61.93963623046875
# i 2, loss 32.227745056152344
# i 3, loss 12.142459869384766
# i 4, loss 1.6651124954223633

# %%
plt.plot(loss_data)
