# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/pytorch/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Neural_Network_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from  sklearn.datasets import make_regression

# %% [markdown]
# #Data 1x1

# %%
x,y=make_regression(n_samples=5,n_features=1,n_targets=1,random_state=True)

# %%
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
plt.scatter(x,y)

# %%
model=torch.nn.Linear(in_features=1,out_features=1)

# %%
critereon=torch.nn.MSELoss()
l=0.1
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=5
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {} , loss {}".format(i,loss.item()))
# Out:
# i 0 , loss 0.5516581535339355
# i 1 , loss 0.43379634618759155
# i 2 , loss 0.3565567135810852
# i 3 , loss 0.3029632568359375
# i 4 , loss 0.24437251687049866

# %%
plt.plot(loss_data)

# %%
x,y=make_regression(n_samples=5,n_features=1,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/10

# %%
plt.scatter(x,y)

# %%
model=torch.nn.Linear(in_features=1,out_features=1)
critereon=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=50
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {} , loss {}".format(i,loss.item()))
# Out:
# i 0 , loss 18.635543823242188
# i 1 , loss 18.619020462036133
# i 2 , loss 18.602863311767578
# i 3 , loss 18.58708953857422
# i 4 , loss 18.57170867919922
# i 5 , loss 18.556737899780273
# i 6 , loss 18.542190551757812
# i 7 , loss 18.528074264526367
# i 8 , loss 18.514406204223633
# i 9 , loss 18.501188278198242
# i 10 , loss 18.488439559936523
# i 11 , loss 18.476154327392578
# i 12 , loss 18.46434211730957
# i 13 , loss 18.4530086517334
# i 14 , loss 18.442153930664062
# i 15 , loss 18.431777954101562
# i 16 , loss 18.421878814697266
# i 17 , loss 18.412452697753906
# i 18 , loss 18.403488159179688
# i 19 , loss 18.39498519897461
# i 20 , loss 18.386926651000977
# i 21 , loss 18.37929916381836
# i 22 , loss 18.372085571289062
# i 23 , loss 18.365270614624023
# i 24 , loss 18.358827590942383
# i 25 , loss 18.352733612060547
# i 26 , loss 18.346960067749023
# i 27 , loss 18.341476440429688
# i 28 , loss 18.33625030517578
# i 29 , loss 18.33124542236328
# i 30 , loss 18.32642364501953
# i 31 , loss 18.321748733520508
# i 32 , loss 18.317176818847656
# i 33 , loss 18.312671661376953
# i 34 , loss 18.308189392089844
# i 35 , loss 18.30369758605957
# i 36 , loss 18.29916000366211
# i 37 , loss 18.294553756713867
# i 38 , loss 18.28984832763672
# i 39 , loss 18.285036087036133
# i 40 , loss 18.280105590820312
# i 41 , loss 18.275060653686523
# i 42 , loss 18.269916534423828
# i 43 , loss 18.264692306518555
# i 44 , loss 18.259424209594727
# i 45 , loss 18.254150390625
# i 46 , loss 18.248918533325195
# i 47 , loss 18.243783950805664
# i 48 , loss 18.238801956176758
# i 49 , loss 18.234037399291992

# %%
plt.plot(loss_data)

# %%
x,y=make_regression(n_samples=6,n_features=1,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
plt.scatter(x,y)

# %%
model=torch.nn.Linear(in_features=1,out_features=1)
critereon=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=50
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {}, loss {}".format(i,loss.item()))
# Out:
# i 0, loss 1.5044251680374146
# i 1, loss 1.4728609323501587
# i 2, loss 1.4427672624588013
# i 3, loss 1.4132667779922485
# i 4, loss 1.384066104888916
# i 5, loss 1.3550385236740112
# i 6, loss 1.3261258602142334
# i 7, loss 1.2973010540008545
# i 8, loss 1.268554925918579
# i 9, loss 1.2398877143859863
# i 10, loss 1.2113075256347656
# i 11, loss 1.1828263998031616
# i 12, loss 1.1544592380523682
# i 13, loss 1.1262233257293701
# i 14, loss 1.098137378692627
# i 15, loss 1.0702217817306519
# i 16, loss 1.042497158050537
# i 17, loss 1.0149844884872437
# i 18, loss 0.9877060651779175
# i 19, loss 0.9606837034225464
# i 20, loss 0.9339393973350525
# i 21, loss 0.907495379447937
# i 22, loss 0.8813735246658325
# i 23, loss 0.8555954694747925
# i 24, loss 0.8301826119422913
# i 25, loss 0.8051561713218689
# i 26, loss 0.7805368304252625
# i 27, loss 0.7563444972038269
# i 28, loss 0.7325990796089172
# i 29, loss 0.7093196511268616
# i 30, loss 0.6865248084068298
# i 31, loss 0.664232611656189
# i 32, loss 0.6424601674079895
# i 33, loss 0.6212243437767029
# i 34, loss 0.6005408763885498
# i 35, loss 0.5804252624511719
# i 36, loss 0.5608919858932495
# i 37, loss 0.5419549942016602
# i 38, loss 0.5236273407936096
# i 39, loss 0.5059216022491455
# i 40, loss 0.4888492822647095
# i 41, loss 0.4724215865135193
# i 42, loss 0.45664867758750916
# i 43, loss 0.4415401220321655
# i 44, loss 0.4271046817302704
# i 45, loss 0.41335052251815796
# i 46, loss 0.400285005569458
# i 47, loss 0.38791483640670776
# i 48, loss 0.37624597549438477
# i 49, loss 0.3652837574481964

# %%
plt.plot(loss_data)

# %% [markdown]
# #Dara 2x1

# %%
x,y=make_regression(n_samples=5,n_features=2,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
model=torch.nn.Linear(in_features=2,out_features=1)
critereon=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=15
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {}, loss {}".format(i,loss.item()))
# Out:
# i 0, loss 0.843249499797821
# i 1, loss 0.8016387820243835
# i 2, loss 0.7630952596664429
# i 3, loss 0.72645103931427
# i 4, loss 0.6913492679595947
# i 5, loss 0.6576679348945618
# i 6, loss 0.6253787875175476
# i 7, loss 0.5944985747337341
# i 8, loss 0.565068244934082
# i 9, loss 0.5371426939964294
# i 10, loss 0.5107846856117249
# i 11, loss 0.48606154322624207
# i 12, loss 0.4630431830883026
# i 13, loss 0.44179996848106384
# i 14, loss 0.4224013388156891

# %%
plt.plot(loss_data)

# %%
x,y=make_regression(n_samples=10,n_features=2,n_targets=1,random_state=True)
x=torch.tensor(x,dtype=torch.float32)
y=torch.tensor(y,dtype=torch.float32)/100

# %%
model=torch.nn.Linear(in_features=2,out_features=1)
criterion=torch.nn.MSELoss()
l=0.01
optimizer=torch.optim.Adam(model.parameters(),lr=l)

# %%
loss_data=[]
epoch=25
for i in range(epoch):
  critereon.zero_grad()
  y_hat=model(x)
  loss=critereon(y_hat,y)
  loss_data.append(loss.item())
  loss.backward()
  optimizer.step()

  if i%1==0:
    print("i {} , loss {}".format(i,loss.item()))
# Out:
# i 0 , loss 1.07761812210083
# i 1 , loss 1.0338985919952393
# i 2 , loss 0.9931419491767883
# i 3 , loss 0.9541230201721191
# i 4 , loss 0.9164595007896423
# i 5 , loss 0.8800127506256104
# i 6 , loss 0.8447413444519043
# i 7 , loss 0.8106508851051331
# i 8 , loss 0.7777723670005798
# i 9 , loss 0.7461509704589844
# i 10 , loss 0.7158410549163818
# i 11 , loss 0.6869021654129028
# i 12 , loss 0.6593976616859436
# i 13 , loss 0.6333914995193481
# i 14 , loss 0.6089486479759216
# i 15 , loss 0.586133599281311
# i 16 , loss 0.5650090575218201
# i 17 , loss 0.545635998249054
# i 18 , loss 0.5280725359916687
# i 19 , loss 0.5123732686042786
# i 20 , loss 0.49858924746513367
# i 21 , loss 0.4867664575576782
# i 22 , loss 0.4769459664821625
# i 23 , loss 0.46916282176971436
# i 24 , loss 0.4634455442428589

# %%
plt.plot(loss_data)
